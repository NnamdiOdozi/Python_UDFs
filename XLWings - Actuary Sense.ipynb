# %%
import pandas as pd
import numpy as np
import xlwings as xw
from scipy.interpolate import interp1d, CubicSpline

# %%
a = np.random.randint(1, 100, 50).reshape(10,5)

# %%
xw.view(a)

# %%
df = pd.read_excel(r"C:\Users\nnamd\OneDrive\Documents\AvE Consulting\Technical\NAS\Yield Curve\July 2023\2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm", header = 5, sheet_name = "SW - Tables", usecols="DM:BGX", index_col = 0, nrows = 14, parse_dates = False)

# %%
df
# Out:
#             0.000000    0.083333    0.166667    0.250000    0.333333    \
# Tenor.2
# 2022-06-30    0.062923         NaN         NaN         NaN         NaN
# 2022-07-31    0.069604         NaN         NaN         NaN         NaN
# 2022-08-31    0.069093         NaN         NaN         NaN         NaN
# 2022-09-30    0.091597         NaN         NaN         NaN         NaN
# 2022-10-31    0.151480         NaN         NaN         NaN         NaN
# 2022-11-30    0.159586         NaN         NaN         NaN         NaN
# 2022-12-31    0.084614         NaN         NaN         NaN         NaN
# 2023-01-31    0.039068         NaN         NaN         NaN         NaN
# 2023-02-28    0.038323         NaN         NaN         NaN         NaN
# 2023-03-31    0.127704         NaN         NaN         NaN         NaN
# 2023-04-30    0.090235         NaN         NaN         NaN         NaN
# 2023-05-31    0.079692         NaN         NaN         NaN         NaN
# ...

# %%
wb = xw.Book()
wb.name = "JupyterTest"
wb.activate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 2
#       1 wb = xw.Book()
# ----> 2 wb.name = "JupyterTest"
#       3 wb.activate()
#
# AttributeError: can't set attribute

# %%
wb.app.quit()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 wb.app.quit()
#
# File ~\OneDrive\Python_learning\Anaconda_Installation\lib\site-packages\xlwings\main.py:1106, in Book.app(self)
#    1099 @property
#    1100 def app(self):
#    1101     """
#    1102     Returns an app object that represents the creator of the book.
#    1103
#    1104     .. versionadded:: 0.9.0
#    1105     """
# -> 1106     return App(impl=self.impl.app)
#
# File ~\OneDrive\Python_learning\Anaconda_Installation\lib\site-packages\xlwings\_xlwindows.py:797, in Book.app(self)
#     795 @property
#     796 def app(self):
# --> 797     return App(xl=self.xl.Application)
#
# File ~\OneDrive\Python_learning\Anaconda_Installation\lib\site-packages\xlwings\_xlwindows.py:186, in COMRetryObjectWrapper.__getattr__(self, item)
#     184 while True:
#     185     try:
# ...

# %%
wb = xw.Book(r"C:\Users\nnamd\OneDrive\Documents\AvE Consulting\Technical\NAS\Yield Curve\July 2023\2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm")

# %%
list(wb.sheets)
# Out:
# [<Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]SW - Tables>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]SW - Tables (Monthly CSBC)>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]SW - Tables (Monthly Linear)>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]LinearInterpolation>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]Sheet1>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]CubicSplineInterpolation_CSBC>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]FMDQ - Interpolated>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]Graphs>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]Testing Data>,
#  <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]Calc Data>]

# %%
wb.sheets[-1]
# Out:
# <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]Calc Data>

# %%
wb.sheets[0].name
# Out:
# 'SW - Tables'

# %%
wb.sheets['SW - Tables']
# Out:
# <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]SW - Tables>

# %%
wb.sheets.add(name='Testing Data', after = 'Graphs')
# Out:
# <Sheet [2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm]Testing Data>

# %% [markdown]
# # How to write a single and multiple values - Horizontally and Vertically

# %%
wb.sheets.add(name='Calc Data', after = 'Testing Data')
Calc_data =wb.sheets['Calc Data']

# %%
Calc_data.range("A1").value = 'Product Name'

# %%
col_list = ["Tenure", "Sum Assured","Premium"]

# %%
Calc_data.range("A2").value = col_list

# %%
#wb = xw.Book()

# %%
#wb.close()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13852\2518608554.py in ?()
# ----> 1 wb.close()
#
# ~\OneDrive\Python_learning\Anaconda_Installation\lib\site-packages\xlwings\main.py in ?(self)
#    1110         Closes the book without saving it.
#    1111
#    1112         .. versionadded:: 0.1.1
#    1113         """
# -> 1114         self.impl.close()
#
# ~\OneDrive\Python_learning\Anaconda_Installation\lib\site-packages\xlwings\_xlwindows.py in ?(self)
#     799     def close(self):
# --> 800         self.xl.Close(SaveChanges=False)
#
# ~\OneDrive\Python_learning\Anaconda_Installation\lib\site-packages\xlwings\_xlwindows.py in ?(self, *args, **kwargs)
#     119                 ) and e.hresult == -2147418111:
#     120                     n_attempt += 1
#     121                     continue
#     122                 else:
# ...

# %%
#app = xw.App()
wb.app.kill()

# %%
# this allows you to load a highlighted range in Excel into Python
df2 = xw.load()

# %%
df2
# Out:
#             0.000000   0.083333   0.166667   0.250000   0.333333   0.416667    \
# Tenor
# 2022-06-30    0.062923       None       None       None       None       None
# 2022-07-31    0.069604       None       None       None       None       None
# 2022-08-31    0.069093       None       None       None       None       None
# 2022-09-30    0.091597       None       None       None       None       None
# 2022-10-31    0.151480       None       None       None       None       None
# 2022-11-30    0.159586       None       None       None       None       None
# 2022-12-31    0.084614       None       None       None       None       None
# 2023-01-31    0.039068       None       None       None       None       None
# 2023-02-28    0.038323       None       None       None       None       None
# 2023-03-31    0.127704       None       None       None       None       None
# 2023-04-30    0.090235       None       None       None       None       None
# ...

# %%
app = xw.App()

# %%
from pathlib import Path
filename = Path("2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm")

# %%
wb = xw.Book(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 wb = xw.Book(filename)
#
# File ~\OneDrive\Python_learning\Anaconda_Installation\lib\site-packages\xlwings\main.py:911, in Book.__init__(self, fullname, update_links, read_only, format, password, write_res_password, ignore_read_only_recommended, origin, delimiter, editable, notify, converter, add_to_mru, local, corrupt_load, impl, json, mode, engine)
#     909     if not app:
#     910         app = App(add_book=False)
# --> 911     impl = app.books.open(
#     912         fullname,
#     913         update_links,
#     914         read_only,
#     915         format,
#     916         password,
#     917         write_res_password,
#     918         ignore_read_only_recommended,
#     919         origin,
#     920         delimiter,
#     921         editable,
#     922         notify,
# ...

# %%
wb = xw.Book(r"C:\Users\nnamd\OneDrive\Documents\AvE Consulting\Technical\NAS\Yield Curve\July 2023\2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm")

# %%
sht = wb.sheets[0]
filename
# Out:
# WindowsPath('2023.07.3 RISK FREE YC JUN 2022 - JUL 2023_3107.xlsm')

# %%
wb = xw.Book()

# %%
app = xw.apps.active

# %%
app.kill()
